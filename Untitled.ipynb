# %%
# !unzip my_archive
# Out:
# Archive:  my_archive.zip
#    creating: .git/
#    creating: __pycache__/
#    creating: caltech101/
#    creating: imgs/
#    creating: models/
#    creating: weights/
#   inflating: README.md
#   inflating: requirements.txt
#   inflating: kmeans.py
#   inflating: opening.ipynb
#   inflating: custom_datasets.py
#   inflating: utils.py
#   inflating: main.py
#   inflating: loader.py
#   inflating: rotation.py
#   inflating: .gitignore
#   inflating: Untitled (1).ipynb
#    creating: .git/branches/
#    creating: .git/hooks/
#    creating: .git/info/
#    creating: .git/logs/
#    creating: .git/objects/
#    creating: .git/refs/
#   inflating: .git/HEAD
#   inflating: .git/packed-refs
#   inflating: .git/description
#   inflating: .git/config
#   inflating: .git/index
#    creating: .git/objects/02/
#    creating: .git/objects/03/
#    creating: .git/objects/05/
#    creating: .git/objects/0b/
#    creating: .git/objects/13/
#    creating: .git/objects/14/
# ...
